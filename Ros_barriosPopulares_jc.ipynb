# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\juanc\\OneDrive\\Escritorio\\Proyectos\\barrios-populares-grupo5\\data\\data.csv')
df
# Out:
#       id_renabap                                           geometry
# 0              1  MULTIPOLYGON (((-58.83350090114561 -34.4812767...  \
# 1              2  MULTIPOLYGON (((-58.01200048352921 -34.9473196...
# 2              3  MULTIPOLYGON (((-58.07980353023293 -35.0350737...
# 3              4  MULTIPOLYGON (((-57.97991397438435 -34.9083356...
# 4              5  MULTIPOLYGON (((-58.06297036682039 -34.9013418...
# ...          ...                                                ...
# 5682        6049  MULTIPOLYGON (((-65.50319405299618 -26.2476513...
# 5683        6050  MULTIPOLYGON (((-65.50501834975279 -26.2469829...
# 5684        6051  MULTIPOLYGON (((-65.49484225523555 -26.2249521...
# 5685        6052  MULTIPOLYGON (((-65.27575508750162 -26.2210999...
# 5686        6053  MULTIPOLYGON (((-65.34836947917938 -26.4816228...
#
#       renabap_id        nombre_barrio     provincia departamento
# 0              1          Monterrey I  Buenos Aires        Pilar  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\juanc\\OneDrive\\Escritorio\\Proyectos\\barrios-populares-grupo5\\data\\data.csv')
df
# Out:
#       id_renabap                                           geometry
# 0              1  MULTIPOLYGON (((-58.83350090114561 -34.4812767...  \
# 1              2  MULTIPOLYGON (((-58.01200048352921 -34.9473196...
# 2              3  MULTIPOLYGON (((-58.07980353023293 -35.0350737...
# 3              4  MULTIPOLYGON (((-57.97991397438435 -34.9083356...
# 4              5  MULTIPOLYGON (((-58.06297036682039 -34.9013418...
# ...          ...                                                ...
# 5682        6049  MULTIPOLYGON (((-65.50319405299618 -26.2476513...
# 5683        6050  MULTIPOLYGON (((-65.50501834975279 -26.2469829...
# 5684        6051  MULTIPOLYGON (((-65.49484225523555 -26.2249521...
# 5685        6052  MULTIPOLYGON (((-65.27575508750162 -26.2210999...
# 5686        6053  MULTIPOLYGON (((-65.34836947917938 -26.4816228...
#
#       renabap_id        nombre_barrio     provincia departamento
# 0              1          Monterrey I  Buenos Aires        Pilar  \
# ...

# %%
df.shape
# Out:
# (5687, 77)

# %%
# Llamamos nuevamente a nuestra varible y le aplicamos el método columns()

df.columns
# Out:
# Index(['id_renabap', 'geometry', 'renabap_id', 'nombre_barrio', 'provincia',
#        'departamento', 'localidad', 'cantidad_viviendas_aproximadas',
#        'cantidad_familias_aproximada', 'decada_de_creacion',
#        'anio_de_creacion', 'energia_electrica', 'efluentes_cloacales',
#        'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
#        'clasificacion_barrio', 'superficie_m2', 'personas_genero_masc',
#        'personas_genero_fem', 'personas_genero_otrx',
#        'responsable_genero_masc', 'responsable_genero_fem',
#        'familia_monoparental_responsable_masculino',
#        'familia_monoparental_responsable_femenino',
#        'cantidad_certificados_entregados',
#        'recibe_asignacion_universal_por_hijo',
#        'no_recibe_asignacion_universal_por_hijo',
#        'no_sabe_si_recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
# ...

# %%
# Creamos la lista que contiene el nombre de las columnas con las cuales nos queremos quedar.

lista_de_columnas_ok = ['nombre_barrio', 'provincia','departamento', 'localidad', 
                                'cantidad_viviendas_aproximadas',
                                'cantidad_familias_aproximada','anio_de_creacion',
                                'energia_electrica', 'efluentes_cloacales',
                                'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
                                'clasificacion_barrio', 'superficie_m2', 'personas_genero_masc',
                                'personas_genero_fem', 'personas_genero_otrx',
                                'recibe_asignacion_universal_por_hijo',
                                'tipo_propiedad_de_quienes_vieven_en_ella',
                                'tipo_propiedad_alquilada',
                                'tipo_propiedad_prestada']

# %%
# Antes de manipular el dataframe es recomendable guardar una variable que contenga el dataset sin modificaciones.
df_crudo = df

# %%
# Ahora si podemos empezar a transformar nuestro dataset.
# Vamos a filtrar las columnas que deseamos trabajar.

df = df[lista_de_columnas_ok]

# %%
# Corroboramos cual es el tamaño de nuestro nuevo df con .shape y .columns

df.shape
# Out:
# (5687, 22)

# %%
df.columns
# Out:
# Index(['nombre_barrio', 'provincia', 'departamento', 'localidad',
#        'cantidad_viviendas_aproximadas', 'cantidad_familias_aproximada',
#        'anio_de_creacion', 'energia_electrica', 'efluentes_cloacales',
#        'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
#        'clasificacion_barrio', 'superficie_m2', 'personas_genero_masc',
#        'personas_genero_fem', 'personas_genero_otrx',
#        'recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada'],
#       dtype='object')

# %%
df.dtypes
# Out:
# nombre_barrio                                object
# provincia                                    object
# departamento                                 object
# localidad                                    object
# cantidad_viviendas_aproximadas              float64
# cantidad_familias_aproximada                float64
# anio_de_creacion                            float64
# energia_electrica                            object
# efluentes_cloacales                          object
# agua_corriente                               object
# cocina                                       object
# calefaccion                                  object
# situacion_dominial                           object
# clasificacion_barrio                         object
# superficie_m2                                 int64
# personas_genero_masc                          int64
# personas_genero_fem                           int64
# personas_genero_otrx                          int64
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     11
# int64       8
# float64     3
# Name: count, dtype: int64

# %%
# Vamos a preguntarle a nuestro dataset con cuantos datos nuelos cuenta

df.isna().any()
# Out:
# nombre_barrio                               False
# provincia                                   False
# departamento                                False
# localidad                                   False
# cantidad_viviendas_aproximadas               True
# cantidad_familias_aproximada                 True
# anio_de_creacion                             True
# energia_electrica                           False
# efluentes_cloacales                         False
# agua_corriente                              False
# cocina                                      False
# calefaccion                                 False
# situacion_dominial                          False
# clasificacion_barrio                        False
# superficie_m2                               False
# personas_genero_masc                        False
# personas_genero_fem                         False
# personas_genero_otrx                        False
# recibe_asignacion_universal_por_hijo        False
# ...

# %%
df.isna().any().sum().sum()
df = df.drop('anio_de_creacion', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 df.isna().any().sum().sum()
# ----> 2 df = df.drop('anio_de_creacion', axis=1)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:5266, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5118 def drop(
#    5119     self,
#    5120     labels: IndexLabel = None,
#    (...)
#    5127     errors: IgnoreRaise = "raise",
#    5128 ) -> DataFrame | None:
#    5129     """
#    5130     Drop specified labels from rows or columns.
#    5131
#    (...)
#    5264             weight  1.0     0.8
#    5265     """
# -> 5266     return super().drop(
#    5267         labels=labels,
#    5268         axis=axis,
#    5269         index=index,
#    5270         columns=columns,
#    5271         level=level,
#    5272         inplace=inplace,
# ...

# %%
print(df.columns)
# Out:
# Index(['nombre_barrio', 'provincia', 'departamento', 'localidad',
#        'cantidad_viviendas_aproximadas', 'cantidad_familias_aproximada',
#        'energia_electrica', 'efluentes_cloacales', 'agua_corriente', 'cocina',
#        'calefaccion', 'situacion_dominial', 'clasificacion_barrio',
#        'superficie_m2', 'personas_genero_masc', 'personas_genero_fem',
#        'personas_genero_otrx', 'recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada'],
#       dtype='object')

# %%
column_name = 'anio_de_creacion'

# Eliminar espacios en blanco adicionales en el nombre de la columna
column_name_stripped = column_name.strip()

# Verificar si la columna existe en el DataFrame
if column_name_stripped in df.columns:
    df = df.drop(column_name_stripped, axis=1)
else:
    print("La columna no existe en el DataFrame.")
# Out:
# La columna no existe en el DataFrame.

# %%
# Con describe() vamos a obtener la totalidad de los datos estadísticos más relevantes
df.describe()
# Out:
#        cantidad_viviendas_aproximadas  superficie_m2  personas_genero_masc
# count                     5686.000000   5.687000e+03           5687.000000  \
# mean                       186.794583   1.037940e+05            176.579216
# std                        473.685766   2.172500e+05            372.146047
# min                          2.000000   3.680000e+02              0.000000
# 25%                         34.000000   1.768000e+04              5.000000
# 50%                         80.000000   4.470300e+04             60.000000
# 75%                        188.000000   1.087780e+05            186.000000
# max                      14000.000000   9.715558e+06           7789.000000
#
#        personas_genero_fem  personas_genero_otrx
# count          5687.000000           5687.000000  \
# mean            191.188500              0.084755
# std             407.825039              0.410714
# min               0.000000              0.000000
# ...

# %%
# Si agregamos el atributo (include='all), nos devuelve también las variables categóricas
df.describe(include='all')
# Out:
#        nombre_barrio     provincia departamento        localidad
# count           5687          5687         5687             5687  \
# unique          4020            24          310              900
# top       Sin Nombre  Buenos Aires      Capital  Córdoba Capital
# freq             150          1933          544              163
# mean             NaN           NaN          NaN              NaN
# std              NaN           NaN          NaN              NaN
# min              NaN           NaN          NaN              NaN
# 25%              NaN           NaN          NaN              NaN
# 50%              NaN           NaN          NaN              NaN
# 75%              NaN           NaN          NaN              NaN
# max              NaN           NaN          NaN              NaN
#
#         cantidad_viviendas_aproximadas            energia_electrica
# count                      5686.000000                         5687  \
# ...

# %%
import pandas as pd
import numpy as np

# Descripción de las columnas numéricas
df.describe(include=np.number)
# Out:
#        cantidad_viviendas_aproximadas  superficie_m2  personas_genero_masc
# count                     5686.000000   5.687000e+03           5687.000000  \
# mean                       186.794583   1.037940e+05            176.579216
# std                        473.685766   2.172500e+05            372.146047
# min                          2.000000   3.680000e+02              0.000000
# 25%                         34.000000   1.768000e+04              5.000000
# 50%                         80.000000   4.470300e+04             60.000000
# 75%                        188.000000   1.087780e+05            186.000000
# max                      14000.000000   9.715558e+06           7789.000000
#
#        personas_genero_fem  personas_genero_otrx
# count          5687.000000           5687.000000  \
# mean            191.188500              0.084755
# std             407.825039              0.410714
# min               0.000000              0.000000
# ...

# %%
# Solo categóricas
df.describe(include =object)
# Out:
#        nombre_barrio     provincia departamento        localidad
# count           5687          5687         5687             5687  \
# unique          4020            24          310              900
# top       Sin Nombre  Buenos Aires      Capital  Córdoba Capital
# freq             150          1933          544              163
#
#                   energia_electrica                     efluentes_cloacales
# count                          5687                                    5687  \
# unique                           10                                       7
# top     Conexión irregular a la red  Desagüe sólo a pozo negro/ciego u hoyo
# freq                           3293                                    3712
#
#                              agua_corriente          cocina    calefaccion
# count                                  5687            5687           5687  \
# unique                                   10               5              7
# ...

# %%
# Pandas nos permite clasificar a las variables de tipo "objeto" al tipo "categórico", permitieno muchas facilidades

df1 = df.select_dtypes( 'object').columns
df1
# Out:
# Index(['nombre_barrio', 'provincia', 'departamento', 'localidad',
#        'energia_electrica', 'efluentes_cloacales', 'agua_corriente', 'cocina',
#        'calefaccion', 'situacion_dominial', 'clasificacion_barrio'],
#       dtype='object')

# %%
df = df.astype({ 'nombre_barrio': 'category',
 'provincia' : 'category',
 'departamento': 'category',
 'localidad' : 'category',
 'energia_electrica' : 'category',
 'efluentes_cloacales' : 'category',
 'agua_corriente': 'category',
 'cocina' : 'category',
 'calefaccion' : 'category',
 'situacion_dominial' : 'category',
 'clasificacion_barrio' : 'category'    
})

# %%
df.describe(include = 'category')
# Out:
#        nombre_barrio     provincia departamento        localidad
# count           5687          5687         5687             5687  \
# unique          4020            24          310              900
# top       Sin Nombre  Buenos Aires      Capital  Córdoba Capital
# freq             150          1933          544              163
#
#                   energia_electrica                     efluentes_cloacales
# count                          5687                                    5687  \
# unique                           10                                       7
# top     Conexión irregular a la red  Desagüe sólo a pozo negro/ciego u hoyo
# freq                           3293                                    3712
#
#                              agua_corriente          cocina    calefaccion
# count                                  5687            5687           5687  \
# unique                                   10               5              7
# ...

# %%
df.select_dtypes(include=[np.number]).mean()
# Out:
# cantidad_viviendas_aproximadas                 186.794583
# superficie_m2                               103793.973976
# personas_genero_masc                           176.579216
# personas_genero_fem                            191.188500
# personas_genero_otrx                             0.084755
# recibe_asignacion_universal_por_hijo            93.722877
# tipo_propiedad_de_quienes_vieven_en_ella       117.778794
# tipo_propiedad_alquilada                         3.375418
# tipo_propiedad_prestada                          4.004396
# dtype: float64

# %%
df.select_dtypes(include=[np.number]).median()
# Out:
# cantidad_viviendas_aproximadas                 80.0
# superficie_m2                               44703.0
# personas_genero_masc                           60.0
# personas_genero_fem                            64.0
# personas_genero_otrx                            0.0
# recibe_asignacion_universal_por_hijo           31.0
# tipo_propiedad_de_quienes_vieven_en_ella       38.0
# tipo_propiedad_alquilada                        0.0
# tipo_propiedad_prestada                         1.0
# dtype: float64

# %%
df.select_dtypes('category').mode()
# Out:
#   nombre_barrio     provincia departamento        localidad
# 0    Sin Nombre  Buenos Aires      Capital  Córdoba Capital  \
#
#              energia_electrica                     efluentes_cloacales
# 0  Conexión irregular a la red  Desagüe sólo a pozo negro/ciego u hoyo  \
#
#                         agua_corriente          cocina    calefaccion
# 0  Conexión irregular a la red de agua  Gas en garrafa  Leña o carbón  \
#
#                  situacion_dominial clasificacion_barrio
# 0  Ninguna seguridad en la tenencia         Asentamiento

# %%
df.columns
# Out:
# Index(['nombre_barrio', 'provincia', 'departamento', 'localidad',
#        'cantidad_viviendas_aproximadas', 'energia_electrica',
#        'efluentes_cloacales', 'agua_corriente', 'cocina', 'calefaccion',
#        'situacion_dominial', 'clasificacion_barrio', 'superficie_m2',
#        'personas_genero_masc', 'personas_genero_fem', 'personas_genero_otrx',
#        'recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada'],
#       dtype='object')

# %%
# Agrupamos los datos por la columna de provincia y sumamos la cantidad de barrios

df.provincia.value_counts()
# Out:
# provincia
# Buenos Aires                       1933
# Santa Fe                            408
# Chaco                               401
# Misiones                            375
# Mendoza                             317
# Tucumán                             298
# Córdoba                             281
# Salta                               233
# Entre Ríos                          212
# Río Negro                           208
# Corrientes                          200
# Jujuy                               141
# Formosa                             111
# Neuquén                             102
# Santiago del Estero                  93
# San Juan                             85
# Chubut                               70
# Ciudad Autónoma de Buenos Aires      50
# Tierra del Fuego                     47
# Catamarca                            41
# San Luis                             30
# La Rioja                             24
# Santa Cruz                           22
# ...

# %%
lista_ros = ['Santa Fe', 'Rosario']
sta_fe = df[df['provincia'].isin(lista_ros)]
sta_fe
# Out:
#                nombre_barrio provincia departamento                localidad
# 1591                 El Piso  Santa Fe      Rosario                  Rosario  \
# 1592  Coronel Aguirre La 680  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1593               Tablita 1  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1594              Los Olivos  Santa Fe      Rosario                  Rosario
# 1595             El Fachinal  Santa Fe      Rosario                    Pérez
# ...                      ...       ...          ...                      ...
# 5547   Calle Doce de Octubre  Santa Fe         Vera                Margarita
# 5548                  Lezama  Santa Fe         Vera                     Vera
# 5549         Zona La Rotonda  Santa Fe         Vera                     Vera
# 5550    San Francisco Solano  Santa Fe         Vera                     Vera
# 5551               Rivadavia  Santa Fe         Vera                     Vera
#
#       cantidad_viviendas_aproximadas
# ...

# %%
#Y si deseamos saber cual es el barrio que mayor cantidad de viviendas posee en la provincia 
sta_fe.sort_values('cantidad_viviendas_aproximadas', ascending=False)[0:1]
# Out:
#      nombre_barrio provincia departamento localidad
# 1707       Cabín 9  Santa Fe      Rosario     Pérez  \
#
#       cantidad_viviendas_aproximadas            energia_electrica
# 1707                          3600.0  Conexión irregular a la red  \
#
#                         efluentes_cloacales
# 1707  Desagüe a cámara séptica y pozo ciego  \
#
#                            agua_corriente          cocina     calefaccion
# 1707  Conexión irregular a la red de agua  Gas en garrafa  Gas en garrafa  \
#
#                     situacion_dominial clasificacion_barrio  superficie_m2
# 1707  Ninguna seguridad en la tenencia         Asentamiento        1072722  \
#
#       personas_genero_masc  personas_genero_fem  personas_genero_otrx
# 1707                  3292                 4103                     1  \
#
#       recibe_asignacion_universal_por_hijo
# 1707                                  1809  \
#
#       tipo_propiedad_de_quienes_vieven_en_ella  tipo_propiedad_alquilada
# ...

# %%
df.sort_values('cantidad_viviendas_aproximadas', ascending=False)
# Out:
#                                       nombre_barrio
# 2385  Padre Rodolfo Ricciardelli (Ex Villa 1-11-14)  \
# 4276            Padre Mugica (Ex Villa 31 y 31 Bis)
# 2397                                       Villa 20
# 2383                                    Villa 21-24
# 251                                  Santa Catalina
# ...                                             ...
# 1570                                Costa Canal III
# 2325                                  Mar del Plata
# 4432                                        Cerrito
# 3620                              Barrio Parque Sur
# 4796                                        Florida
#
#                             provincia        departamento
# 2385  Ciudad Autónoma de Buenos Aires            Comuna 7  \
# 4276  Ciudad Autónoma de Buenos Aires            Comuna 1
# 2397  Ciudad Autónoma de Buenos Aires            Comuna 8
# 2383  Ciudad Autónoma de Buenos Aires            Comuna 4
# ...

# %%
df[df['provincia'] == 'Santa Fe'].departamento.unique()[10:20]
# Out:
# ['Castellanos', 'San Cristóbal', 'San Martín', '9 de julio', 'Constitución', 'Iriondo', 'San Javier', 'Belgrano', 'San Justo']
# Categories (310, object): ['12 de octubre', '1° de Mayo', '2 de abril', '25 de mayo', ..., 'Yaví', 'Yerba Buena', 'Zapala', 'Zárate']

# %%
# Siguamos filtrando con distintas condicionales
# Podemos llamar que nos devuelva siguiendo determinadas condiciones, por ejemplo, podemos pedir que regrese los valores
# de la provincia Chaco, el departamento General Guemes, y aquellos barrios que tengan Conexión irregular a la red de energia

df[(df['provincia'] == 'Santa Fe') & (df['localidad'] == 'Rosario') & (df['energia_electrica'] == 'Conexión irregular a la red')]
# Out:
#         nombre_barrio provincia departamento localidad
# 1591          El Piso  Santa Fe      Rosario   Rosario  \
# 1599        La Vincha  Santa Fe      Rosario   Rosario
# 1600        Refinería  Santa Fe      Rosario   Rosario
# 1601     Villa Banana  Santa Fe      Rosario   Rosario
# 1603        Barrio 27  Santa Fe      Rosario   Rosario
# ...               ...       ...          ...       ...
# 1758  Villa Manuelita  Santa Fe      Rosario   Rosario
# 4322     Monte Flores  Santa Fe      Rosario   Rosario
# 4323       El Gráfico  Santa Fe      Rosario   Rosario
# 4328        El Humito  Santa Fe      Rosario   Rosario
# 4329         Tío Rolo  Santa Fe      Rosario   Rosario
#
#       cantidad_viviendas_aproximadas            energia_electrica
# 1591                           325.0  Conexión irregular a la red  \
# 1599                            60.0  Conexión irregular a la red
# 1600                            55.0  Conexión irregular a la red
# ...

# %%
Santa_fe = df[df['provincia'] == 'Santa Fe']
Santa_fe
# Out:
#                nombre_barrio provincia departamento                localidad
# 1591                 El Piso  Santa Fe      Rosario                  Rosario  \
# 1592  Coronel Aguirre La 680  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1593               Tablita 1  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1594              Los Olivos  Santa Fe      Rosario                  Rosario
# 1595             El Fachinal  Santa Fe      Rosario                    Pérez
# ...                      ...       ...          ...                      ...
# 5547   Calle Doce de Octubre  Santa Fe         Vera                Margarita
# 5548                  Lezama  Santa Fe         Vera                     Vera
# 5549         Zona La Rotonda  Santa Fe         Vera                     Vera
# 5550    San Francisco Solano  Santa Fe         Vera                     Vera
# 5551               Rivadavia  Santa Fe         Vera                     Vera
#
#       cantidad_viviendas_aproximadas
# ...

# %%
#calculo de como se distribuyen los barrios populares
Santa_fe['departamento'].value_counts(ascending=True)
# Out:
# departamento
# 12 de octubre         0
# Ojo de Agua           0
# Oberá                 0
# O'Higgins             0
# Nogoyá                0
#                    ...
# San Jerónimo         17
# San Lorenzo          23
# General Obligado     31
# La Capital           88
# Rosario             163
# Name: count, Length: 310, dtype: int64

# %%
Santa_fe = Santa_fe.astype({ 'nombre_barrio': 'object',
 'provincia' : 'object',
 'departamento': 'object',
 'localidad' : 'object',
 'energia_electrica' : 'object',
 'efluentes_cloacales' : 'object',
 'agua_corriente': 'object',
 'cocina' : 'object',
 'calefaccion' : 'object',
 'situacion_dominial' : 'object',
 'clasificacion_barrio' : 'object' 
})

# %%
Santa_fe.departamento.value_counts()
# Out:
# departamento
# Rosario             163
# La Capital           88
# General Obligado     31
# San Lorenzo          23
# San Jerónimo         17
# Constitución         10
# Las Colonias         10
# Vera                  9
# General López         8
# Garay                 8
# Castellanos           7
# San Javier            7
# San Cristóbal         6
# Iriondo               6
# 9 de julio            5
# Caseros               4
# San Martín            4
# Belgrano              1
# San Justo             1
# Name: count, dtype: int64

# %%
Santa_fe.departamento.value_counts() * 100 / (len(Santa_fe.departamento))
# Out:
# departamento
# Rosario             39.950980
# La Capital          21.568627
# General Obligado     7.598039
# San Lorenzo          5.637255
# San Jerónimo         4.166667
# Constitución         2.450980
# Las Colonias         2.450980
# Vera                 2.205882
# General López        1.960784
# Garay                1.960784
# Castellanos          1.715686
# San Javier           1.715686
# San Cristóbal        1.470588
# Iriondo              1.470588
# 9 de julio           1.225490
# Caseros              0.980392
# San Martín           0.980392
# Belgrano             0.245098
# San Justo            0.245098
# Name: count, dtype: float64

# %%
rosario = Santa_fe[Santa_fe['departamento'] == 'Rosario']
rosario
# Out:
#                nombre_barrio provincia departamento                localidad
# 1591                 El Piso  Santa Fe      Rosario                  Rosario  \
# 1592  Coronel Aguirre La 680  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1593               Tablita 1  Santa Fe      Rosario  Villa Gobernador Gálvez
# 1594              Los Olivos  Santa Fe      Rosario                  Rosario
# 1595             El Fachinal  Santa Fe      Rosario                    Pérez
# ...                      ...       ...          ...                      ...
# 4327              Zona Rural  Santa Fe      Rosario      Granadero Baigorria
# 4328               El Humito  Santa Fe      Rosario                  Rosario
# 4329                Tío Rolo  Santa Fe      Rosario                  Rosario
# 5045                Malvinas  Santa Fe      Rosario           Coronel Bogado
# 5046   Ruta 18 - Kilómetro 1  Santa Fe      Rosario                   Piñero
#
#       cantidad_viviendas_aproximadas
# ...

# %%
rosario.localidad.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
ros1 = rosario[rosario['localidad'] == 'Rosario']
ros1
# Out:
#                    nombre_barrio provincia departamento localidad
# 1591                     El Piso  Santa Fe      Rosario   Rosario  \
# 1594                  Los Olivos  Santa Fe      Rosario   Rosario
# 1599                   La Vincha  Santa Fe      Rosario   Rosario
# 1600                   Refinería  Santa Fe      Rosario   Rosario
# 1601                Villa Banana  Santa Fe      Rosario   Rosario
# ...                          ...       ...          ...       ...
# 4044  Arroyito Norte Ferrocarril  Santa Fe      Rosario   Rosario
# 4322                Monte Flores  Santa Fe      Rosario   Rosario
# 4323                  El Gráfico  Santa Fe      Rosario   Rosario
# 4328                   El Humito  Santa Fe      Rosario   Rosario
# 4329                    Tío Rolo  Santa Fe      Rosario   Rosario
#
#       cantidad_viviendas_aproximadas
# 1591                           325.0  \
# 1594                           200.0
# 1599                            60.0
# ...

# %%
ros1.reset_index(drop=True, inplace=True)

# %%
ros1
# Out:
#                   nombre_barrio provincia departamento localidad
# 0                       El Piso  Santa Fe      Rosario   Rosario  \
# 1                    Los Olivos  Santa Fe      Rosario   Rosario
# 2                     La Vincha  Santa Fe      Rosario   Rosario
# 3                     Refinería  Santa Fe      Rosario   Rosario
# 4                  Villa Banana  Santa Fe      Rosario   Rosario
# ..                          ...       ...          ...       ...
# 105  Arroyito Norte Ferrocarril  Santa Fe      Rosario   Rosario
# 106                Monte Flores  Santa Fe      Rosario   Rosario
# 107                  El Gráfico  Santa Fe      Rosario   Rosario
# 108                   El Humito  Santa Fe      Rosario   Rosario
# 109                    Tío Rolo  Santa Fe      Rosario   Rosario
#
#      cantidad_viviendas_aproximadas
# 0                             325.0  \
# 1                             200.0
# 2                              60.0
# ...

# %%
# Podemos sumar la cantidad de familias que viven en barrios populares en castelli
# También podemos sumar la cantidad de viviendas que hay en barrios populares en castelli

ros1.cantidad_viviendas_aproximadas.sum()
# Out:
# 35130.0

# %%
ros1.groupby(['nombre_barrio']).cantidad_viviendas_aproximadas.sum().sort_values(ascending=False)
# Out:
# nombre_barrio
# Ludueña                3500.0
# Bella Vista            1985.0
# Nuevo Alberdi Oeste    1800.0
# Los Pumitas            1500.0
# Triángulo              1300.0
#                         ...
# Imperiale                20.0
# San Martín A             20.0
# Barrio Itatí             16.0
# Los Olivos 2             13.0
# Antártida Argentina      11.0
# Name: cantidad_viviendas_aproximadas, Length: 105, dtype: float64

# %%
ros1.groupby(['nombre_barrio']).personas_genero_masc.sum().sort_values(ascending=False)
# Out:
# nombre_barrio
# Ludueña                1999
# Nuevo Alberdi Oeste    1901
# Bella Vista            1696
# Los Pumitas            1643
# Cullen                 1430
#                        ...
# Los Olivos 2             11
# Belgrano                  9
# Monte Flores              0
# El Humito                 0
# El Gráfico                0
# Name: personas_genero_masc, Length: 105, dtype: int64

# %%
ros1.groupby('nombre_barrio').agg(['sum', 'count'])
# Out:
#                                    provincia          departamento
#                                          sum count             sum count
# nombre_barrio
# Amistad                             Santa Fe     1         Rosario     1  \
# Antártida Argentina                 Santa Fe     1         Rosario     1
# Arroyito                    Santa FeSanta Fe     2  RosarioRosario     2
# Arroyito Norte Ferrocarril          Santa Fe     1         Rosario     1
# Azcuénaga                           Santa Fe     1         Rosario     1
# ...                                      ...   ...             ...   ...
# Villa Manuelita                     Santa Fe     1         Rosario     1
# Villa Oculta                        Santa Fe     1         Rosario     1
# Villa Pororó                        Santa Fe     1         Rosario     1
# Villa Tablada                       Santa Fe     1         Rosario     1
# Zona Rural                          Santa Fe     1         Rosario     1
#
# ...

# %%
ros1.groupby('localidad').agg({'cantidad_viviendas_aproximadas': ['min','max']})
# Out:
#           cantidad_viviendas_aproximadas
#                                      min     max
# localidad
# Rosario                             11.0  3500.0

# %%
ros1.columns
# Out:
# Index(['nombre_barrio', 'provincia', 'departamento', 'localidad',
#        'cantidad_viviendas_aproximadas', 'energia_electrica',
#        'efluentes_cloacales', 'agua_corriente', 'cocina', 'calefaccion',
#        'situacion_dominial', 'clasificacion_barrio', 'superficie_m2',
#        'personas_genero_masc', 'personas_genero_fem', 'personas_genero_otrx',
#        'recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada'],
#       dtype='object')

# %%
ros1.groupby('nombre_barrio').agg({'personas_genero_masc': 'sum', 'personas_genero_fem' : 'sum', 'personas_genero_otrx': 'sum'})
# Out:
#                             personas_genero_masc  personas_genero_fem
# nombre_barrio
# Amistad                                      110                  125  \
# Antártida Argentina                           26                   16
# Arroyito                                     438                  426
# Arroyito Norte Ferrocarril                    31                   31
# Azcuénaga                                     50                   41
# ...                                          ...                  ...
# Villa Manuelita                               66                   74
# Villa Oculta                                 469                  449
# Villa Pororó                                 223                  243
# Villa Tablada                               1192                 1223
# Zona Rural                                   373                  371
#
#                             personas_genero_otrx
# nombre_barrio
# ...

# %%
genero_barrios = ros1.groupby('nombre_barrio').agg({'personas_genero_masc': 'sum', 'personas_genero_fem' : 'sum', 'personas_genero_otrx': 'sum'})

genero_barrios
# Out:
#                             personas_genero_masc  personas_genero_fem
# nombre_barrio
# Amistad                                      110                  125  \
# Antártida Argentina                           26                   16
# Arroyito                                     438                  426
# Arroyito Norte Ferrocarril                    31                   31
# Azcuénaga                                     50                   41
# ...                                          ...                  ...
# Villa Manuelita                               66                   74
# Villa Oculta                                 469                  449
# Villa Pororó                                 223                  243
# Villa Tablada                               1192                 1223
# Zona Rural                                   373                  371
#
#                             personas_genero_otrx
# nombre_barrio
# ...

# %%
categoricas = ['energia_electrica', 'efluentes_cloacales',
       'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
       'clasificacion_barrio']

numericas = ['superficie_m2',  'cantidad_viviendas_aproximadas',
       'cantidad_familias_aproximada']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Graficos
categoricas = ['energia_electrica', 'efluentes_cloacales',
       'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
       'clasificacion_barrio']

numericas = ['superficie_m2',  'cantidad_viviendas_aproximadas',
       'cantidad_familias_aproximada']

for categoria in categoricas:
    frecuencia = ros1[categoria].value_counts()
    df_frecuencia = pd.DataFrame({categoria: frecuencia.index.tolist(), 'frecuencia': frecuencia.tolist()})
    plt.figure(figsize=(15, 8))
    sns.barplot(x=categoria, y='frecuencia', data=df_frecuencia)
    plt.show()

# %%
for categoria in categoricas:
    frecuencia = df[categoria].value_counts()
    df_frecuencia = pd.DataFrame({categoria: frecuencia.index.tolist(), 'frecuencia': frecuencia.tolist()})
    plt.figure(figsize = (15,8))
    sns.barplot(x=categoria, y='frecuencia', data=df_frecuencia)
    plt.show()

# %%
ros1.energia_electrica.value_counts().plot.pie(autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='count'>

# %%
ros1.energia_electrica.value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='energia_electrica'>

# %%
ros1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   nombre_barrio                             110 non-null    object
#  1   provincia                                 110 non-null    object
#  2   departamento                              110 non-null    object
#  3   localidad                                 110 non-null    object
#  4   cantidad_viviendas_aproximadas            110 non-null    float64
#  5   energia_electrica                         110 non-null    object
#  6   efluentes_cloacales                       110 non-null    object
#  7   agua_corriente                            110 non-null    object
#  8   cocina                                    110 non-null    object
#  9   calefaccion                               110 non-null    object
# ...

# %%
ros1.efluentes_cloacales.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
ros1.efluentes_cloacales.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='count'>

# %%
ros1.agua_corriente.value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='agua_corriente'>

# %%
plt.figure (figsize=(15,10))
sns.countplot(data = ros1, x='energia_electrica', hue='cocina')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure (figsize=(15,10))
sns.countplot(data = ros1, x='efluentes_cloacales')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ros1.select_dtypes('int64').columns
# Out:
# Index(['superficie_m2', 'personas_genero_masc', 'personas_genero_fem',
#        'personas_genero_otrx', 'recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada'],
#       dtype='object')

# %%
ros1['total_habitante'] = ros1['personas_genero_masc'] + ros1['personas_genero_fem'] + ros1['personas_genero_otrx']
ros1
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_2224\3021139628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ros1['total_habitante'] = ros1['personas_genero_masc'] + ros1['personas_genero_fem'] + ros1['personas_genero_otrx']
#                   nombre_barrio provincia departamento localidad
# 0                       El Piso  Santa Fe      Rosario   Rosario  \
# 1                    Los Olivos  Santa Fe      Rosario   Rosario
# 2                     La Vincha  Santa Fe      Rosario   Rosario
# 3                     Refinería  Santa Fe      Rosario   Rosario
# 4                  Villa Banana  Santa Fe      Rosario   Rosario
# ..                          ...       ...          ...       ...
# ...

# %%
ros1[['nombre_barrio', 'cantidad_viviendas_aproximadas','personas_genero_masc', 'personas_genero_fem', 'personas_genero_otrx', 'total_habitante']]
# Out:
#                   nombre_barrio  cantidad_viviendas_aproximadas
# 0                       El Piso                           325.0  \
# 1                    Los Olivos                           200.0
# 2                     La Vincha                            60.0
# 3                     Refinería                            55.0
# 4                  Villa Banana                          1100.0
# ..                          ...                             ...
# 105  Arroyito Norte Ferrocarril                            20.0
# 106                Monte Flores                            20.0
# 107                  El Gráfico                            20.0
# 108                   El Humito                            50.0
# 109                    Tío Rolo                           130.0
#
#      personas_genero_masc  personas_genero_fem  personas_genero_otrx
# 0                     262                  250                     0  \
# ...
